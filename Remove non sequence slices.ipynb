# %%
import pydicom
import os

# %%
path = '/Users/tbarfoot/Documents/MALIMAR_data_cleaning/temp/dicoms/b50/20160830_141417_Avanto/scans/71-B50/resources/DICOM/files'

# %%
for dirName, subdirList, fileList in os.walk(path):
    for filename in fileList:
        if ".dcm" in filename.lower():
            dcm_path = os.path.join(dirName, filename)
            dcm = pydicom.dcmread(dcm_path, stop_before_pixels=True)
            if dcm.SequenceName == 'ep_b600t':
                os.remove(dcm_path)

# %%
path = '/Users/tbarfoot/Downloads/scans 5/51_AXIAL B50/DICOM'

# %%
for dirName, subdirList, fileList in os.walk(path):
    for filename in fileList:
        if ".dcm" in filename.lower():
            dcm_path = os.path.join(dirName, filename)
            dcm = pydicom.dcmread(dcm_path, stop_before_pixels=True)
            print(dcm.SequenceName)
# Out:
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ep_b50t
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('df.csv')
df.drop('Slice', axis=1, inplace=True)  # for some reason df has a slice column, check in real code
df.set_index(['Sequence', 'Series', 'InstanceNumber'], drop=False, inplace=True)
df.drop(['Sequence', 'Series'], axis=1, inplace=True)  # Keep InstanceNumber column
df.rename_axis(index={'InstanceNumber': 'Slice'}, inplace=True)

for idx, d in df.groupby(['Sequence', 'Series']):
    if d.SequenceName.nunique() != 1:
        seq = d.SequenceName.value_counts().idxmax()
        for i, row in df.loc[idx].iterrows():
            if row['SequenceName'] != seq:
                print('ye', idx + (i,))
                df.drop(idx + (i,), inplace=True)
# Out:
# ye ('diffusion', 'b50', 251)

# %%
for idx, d in df.groupby(['Sequence', 'Series']):
    if d.SequenceName.nunique() != 1:
        print(d.SequenceName)

# %%
a != seq
# Out:
# True

# %%
idx + (i,)
# Out:
# ('dixon', 'water', 250)

# %%
df_new
# Out:
#       Sequence Series  Slice  SeriesNumber SequenceName  InstanceNumber  \
# 500  diffusion    b50    251             5     ep_b900t             251
#
#      SliceLocation  SliceThickness  Rows  Columns  \
# 500   -1021.663277             5.0   224      280
#
#                            PixelSpacing  \
# 500  [1.5357142686844, 1.5357142686844]
#
#                                   ImagePositionPatient  \
# 500  [-213.55362772942, -194.99390792847, -1021.663...
#
#                                      SeriesInstanceUID  \
# 500  1.3.12.2.1107.5.99.2.2137.30000017072010170984...
#
#                                         SOPInstanceUID  \
# 500  1.3.12.2.1107.5.99.2.2137.30000017072010170984...
#
#                                                   Path
# 500  temp/dicoms/b50/20170720_152016_Avanto/scans/5...
